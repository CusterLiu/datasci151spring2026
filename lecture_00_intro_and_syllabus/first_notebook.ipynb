# %% [markdown]
# <font size = "10">
# This is my first Jupyter notebook

# %%
print("My name is Peiyu Liu")
# Out:
# My name is Peiyu Liu

# %% [markdown]
# when something off in edited version - go github and download raw - original copy
# - the masterupstream repo - recover file
