# %% [markdown]
# Title and student IDs of project members
# <br>Project Title: "
# <br>
# Student IDs: Peiyu（Custer） Liu

# %% [markdown]
# Introduction：
# <br>

# %% [markdown]
# Data Description:
# <br>1. dataset table:
# <br>2. merging process
# <br>3. data cleaning procedure
# <br>4. main columns

# %% [markdown]
# Results:
# <br>

# %% [markdown]
# Discussion:
# <br>

# %%
import pandas as pd 
import matplotlib.pyplot as plt
